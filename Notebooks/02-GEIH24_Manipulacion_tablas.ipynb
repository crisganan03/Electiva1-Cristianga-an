# %%
# importando librerias necesarias para el analisis de la GEIH
import pandas as pd
import numpy as np

# %%
#leyendo los datos de la GEIH
df_cgsse = pd.read_csv("https://raw.githubusercontent.com/niconomist98/DataAnalyticsUQ/refs/heads/main/Datos/GEIH2025/cgsse.CSV"
                       ,encoding="latin", sep=";")

df_fuerzatrabajo = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV"
                               ,encoding="latin",sep=";")

df_NoOcupados = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/No%20ocupados.CSV"
                            ,encoding="latin",sep=";")

df_Ocupados = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Ocupados.CSV"
                          ,encoding="latin", sep=";")
# Out:
# /tmp/ipykernel_2460/2963210141.py:5: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_fuerzatrabajo = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Fuerza%20de%20trabajo.CSV"
# /tmp/ipykernel_2460/2963210141.py:11: DtypeWarning: Columns (28,89,133,147,158) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_Ocupados = pd.read_csv("https://github.com/niconomist98/DataAnalyticsUQ/raw/refs/heads/main/Datos/GEIH2025/Ocupados.CSV"

# %%
df_fuerzatrabajo
# Out:
#         PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  \
# 0      20250626    6  2025     8238974            1      1      1     50
# 1      20250626    6  2025     8238974            1      2      1     50
# 2      20250626    6  2025     8238975            1      1      1     50
# 3      20250626    6  2025     8238975            1      2      1     50
# 4      20250626    6  2025     8238975            1      3      1     50
# ...         ...  ...   ...         ...          ...    ...    ...    ...
# 54445  20250626    6  2025     8283060            1      1      1     50
# 54446  20250626    6  2025     8283060            1      2      1     50
# 54447  20250626    6  2025     8283062            1      1      1     50
# 54448  20250626    6  2025     8283062            1      2      1     50
# 54449  20250626    6  2025     8283062            1      3      1     50
#
#        AREA  CLASE  ...  P3362S8  P3362S7A1  P6300  P6310  P6310S1  P6320  \
# ...

# %%
#nueva celda para el ejemplo del commit
df_Ocupados.head()
# Out:
#     PERIODO  MES   PER  DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  REGIS  AREA  \
# 0  20250626    6  2025     8238974            1      1      1     60   NaN
# 1  20250626    6  2025     8238974            1      2      1     60   NaN
# 2  20250626    6  2025     8238975            1      1      1     60   NaN
# 3  20250626    6  2025     8238975            1      3      1     60   NaN
# 4  20250626    6  2025     8238976            1      1      1     60   NaN
#
#    CLASE  ...  P1881  P1881S1  P1882  P7240  P7240S1  OCI    INGLABO  \
# 0      2  ...      3      NaN    3.0      3      NaN    1   950000.0
# 1      2  ...      3      NaN    4.0      5      NaN    1        NaN
# 2      2  ...      3      NaN   10.0      3      NaN    1   700000.0
# 3      2  ...      3      NaN   10.0      3      NaN    1  2000000.0
# 4      2  ...     14      NaN    NaN      8      NaN    1   600000.0
#
#    RAMA2D_R4  RAMA4D_R4  OFICIO_C8
# 0          1        113       6111
# ...
